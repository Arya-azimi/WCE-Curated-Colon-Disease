# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s-cls.pt")

# %%
model.train(
    data="../data",
    epochs=10,
    imgsz=224,
    batch=16,
    device="cpu",
)
# Out:
# Ultralytics 8.4.53 🚀 Python-3.12.3 torch-2.12.0+cu130 CPU (AMD Ryzen 5 PRO 4650U with Radeon Graphics)
# ...
